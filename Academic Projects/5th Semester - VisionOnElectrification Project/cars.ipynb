# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cars_2018=pd.read_csv('dados/2018.csv',low_memory=False)
cars_2019=pd.read_csv('dados/2019.csv',low_memory=False)
cars_2020=pd.read_csv('dados/2020.csv',low_memory=False)

# %%
cars=cars_2018.append([cars_2019,cars_2020])

# %%
cars
# Out:
#                  ID Country                        VFN           Mp  \
# 0            280060      DK                        NaN  SUZUKI POOL
# 1            280061      DK                        NaN  SUZUKI POOL
# 2            280062      DK                        NaN  SUZUKI POOL
# 3            280063      DK                        NaN  SUZUKI POOL
# 4            280064      DK                        NaN  SUZUKI POOL
# ...             ...     ...                        ...          ...
# 11742434  162072100      GB  IP-0014-JF1-1                      NaN
# 11742435  162072200      GB  IP-13-JF1-2017-0001                NaN
# 11742436  162072300      GB  IP-0014-JF1-1                      NaN
# 11742437  162072400      GB  IP-13-JF1-2017-0001                NaN
# 11742438  162072500      GB                        NaN          NaN
#
#                                 Mh                       Man  \
# 0         SUZUKI MOTOR CORPORATION  SUZUKI MOTOR CORPORATION
# ...

# %%
cars.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10372\3570679698.py in <module>
# ----> 1 cars_2018.info()
#
# NameError: name 'cars_2018' is not defined

# %%
cars['year'] = pd.to_datetime(cars['year'], format='%Y')

# %%
cars.isnull().sum()
# Out:
# ID                             0
# Country                     1193
# VFN                     13616259
# Mp                       2116601
# Mh                             0
# Man                          866
# MMS                      1333854
# Tan                        82280
# T                          17904
# Va                         65452
# Ve                         80292
# Mk                         51964
# Cn                         40862
# Ct                        155368
# Cr                        757240
# r                              0
# m (kg)                      1795
# Mt                      11755499
# Enedc (g/km)               27175
# Ewltp (g/km)            11228614
# W (mm)                     91573
# At1 (mm)                  117695
# At2 (mm)                  291475
# Ft                         23454
# Fm                          3082
# ec (cm3)                 1243004
# ep (KW)                  5200588
# z (Wh/km)               40875795
# ...

# %%
cars_2018.dropna(subset=['ID','Country','Mk','Cn','m (kg)','Ft'],inplace=True)

# %%
ECars_Sales=cars[cars['Ft'].isin([ 'Petrol/Electric','PETROL/ELECTRIC','ELECTRIC','Diesel/Electric','DIESEL/ELECTRIC ','Diesel/electric','petrol/electric']) ]  
ECars_Sales
# Out:
#                 ID Country                       VFN             Mp  \
# 1436        281496      DK                       NaN      BMW GROUP
# 1437        281497      DK                       NaN      BMW GROUP
# 1438        281498      DK                       NaN      BMW GROUP
# 1439        281499      DK                       NaN      BMW GROUP
# 25732       136267      DK                       NaN     DAIMLER AG
# ...            ...     ...                       ...            ...
# 11741550  37337612      AT                       NaN  MERCEDES-BENZ
# 11741551  37337996      AT  IP-4_ZS11E_01_2019-LSJ-1        VW-SAIC
# 11741552  37340202      AT  IP-04-KNA-2018-1079                 KIA
# 11741553  37340440      AT  IP-4_ZS11E_01_2019-LSJ-1        VW-SAIC
# 11741554  37340956      AT  IP-04-KNA-2018-1145                 KIA
#
#                               Mh                          Man  \
# 1436                      BMW AG  BAYERISCHE MOTOREN WERKE AG
# ...

# %%
cars.describe()
# Out:
#                  ID        m (kg)  Enedc (g/km)  Ewltp (g/km)        W (mm)  \
# count  1.549973e+07  1.549959e+07  1.549296e+07  1.498939e+07  1.548308e+07
# mean   7.749865e+06  1.418066e+03  1.223783e+02  1.473197e+02  2.648067e+03
# std    4.474387e+06  2.933407e+02  3.230370e+01  3.640650e+01  1.714300e+02
# min    1.000000e+00  5.200000e+02  0.000000e+00  0.000000e+00  1.000000e+03
# 25%    3.874933e+06  1.195000e+03  1.100000e+02  1.320000e+02  2.551000e+03
# 50%    7.749864e+06  1.385000e+03  1.200000e+02  1.450000e+02  2.640000e+03
# 75%    1.162480e+07  1.580000e+03  1.360000e+02  1.630000e+02  2.705000e+03
# max    1.600002e+07  5.255000e+03  5.750000e+02  5.750000e+02  4.895000e+03
#
#            At1 (mm)      At2 (mm)      ec (cm3)       ep (KW)      z (Wh/km)  \
# count  1.546419e+07  1.542639e+07  1.515338e+07  1.350179e+07  342780.000000
# mean   1.543205e+03  1.540976e+03  1.540691e+03  9.953112e+01     166.948678
# ...

# %%
cars_2018.drop(['VFN','Mp','Mh','Man','MMS','Tan','T','Va','Ve','Ct','Cr','Mt','Ewltp (g/km)','W (mm)','At1 (mm)','At2 (mm)','Fm','z (Wh/km)','IT','Ernedc (g/km)','Erwltp (g/km)','De','Vf','Status','Fuel Consumption','year',"Date of registration"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12220\3949124237.py in <module>
# ----> 1 cars_2018.drop(['VFN','Mp','Mh','Man','MMS','Tan','T','Va','Ve','Ct','Cr','Mt','Ewltp (g/km)','W (mm)','At1 (mm)','At2 (mm)','Fm','z (Wh/km)','IT','Ernedc (g/km)','Erwltp (g/km)','De','Vf','Status','Fuel Consumption','year',"Date of registration"], axis=1)
#
# c:\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# c:\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# ...

# %%
E2018=cars[(cars.Ft=='ELECTRIC') | (cars.Ft=='PETROL/ELECTRIC') | (cars.Ft=='DIESEL/ELECTRIC')& (cars.year==2018)]
E2019=cars[(cars.Ft=='ELECTRIC') | (cars.Ft=='PETROL/ELECTRIC') | (cars.Ft=='DIESEL/ELECTRIC') & (cars.year==2019)]
E2020=cars[(cars.Ft=='ELECTRIC') | (cars.Ft=='PETROL/ELECTRIC') | (cars.Ft=='DIESEL/ELECTRIC') & (cars.year==2020)]

P2018=cars[(cars.Ft=='PETROL')| (cars.Ft=='DIESEL') & (cars.year==2018)]
P2019=cars[(cars.Ft=='PETROL')| (cars.Ft=='DIESEL')  & (cars.year==2019)]
P2020=cars[(cars.Ft=='PETROL')| (cars.Ft=='DIESEL')  & (cars.year==2020)]



df=[[E2018['Ft'].count(),P2018['Ft'].count()],[E2019['Ft'].count(),P2019['Ft'].count()],[E2020['Ft'].count(),P2020['Ft'].count()]]

ind=[['2018','2019','2020']]
preditct=pd.DataFrame(df,columns=['ELECTRIC','COMBUSTAO'])
preditct


sns.heatmap(df.corr(),cmap="YlGnBu",annot=True,linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6276\1751632572.py in <module>
# ----> 1 E2018=cars[(cars.Ft=='ELECTRIC') | (cars.Ft=='PETROL/ELECTRIC') | (cars.Ft=='DIESEL/ELECTRIC')& (cars.year==2018)]
#       2 E2019=cars[(cars.Ft=='ELECTRIC') | (cars.Ft=='PETROL/ELECTRIC') | (cars.Ft=='DIESEL/ELECTRIC') & (cars.year==2019)]
#       3 E2020=cars[(cars.Ft=='ELECTRIC') | (cars.Ft=='PETROL/ELECTRIC') | (cars.Ft=='DIESEL/ELECTRIC') & (cars.year==2020)]
#       4
#       5 P2018=cars[(cars.Ft=='PETROL')| (cars.Ft=='DIESEL') & (cars.year==2018)]
#
# c:\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
# ...

# %%
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True,linewidth=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6276\3424933741.py in <module>
# ----> 1 sns.heatmap(df.corr(),cmap="YlGnBu",annot=True,linewidth=1)
#
# NameError: name 'df' is not defined

# %%
x=preditct['ELECTRIC'].values
y=preditct['PETROL'].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6276\322244084.py in <module>
# ----> 1 x=preditct['ELECTRIC'].values
#       2 y=preditct['PETROL'].values
#       3 from sklearn.model_selection import train_test_split
#       4 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)
#
# NameError: name 'preditct' is not defined

# %%
sns.heatmap(cars_2018.corr(),cmap="YlGnBu",annot=True,linewidth=1)
# Out:
# <AxesSubplot:>
